# %% [markdown]
# # Exploring Alpha Vantage API

# %% [markdown]
# ### Imports- **Run First**

# %%
#open file with your API key
with open('Alpha_Vintage_API_Key.txt') as file:
    API_key = file.read()
API_key = API_key.strip()

# %% [markdown]
# ### How to pull stock data with the alpha_vantage Python package 1

# %%
#install Alpha Vantage Python package
# %pip install alpha_vantage
# Out:
# Collecting alpha_vantage
#   Downloading alpha_vantage-2.3.1-py3-none-any.whl (31 kB)
# Collecting aiohttp (from alpha_vantage)
#   Downloading aiohttp-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from alpha_vantage) (2.31.0)
# Collecting aiosignal>=1.1.2 (from aiohttp->alpha_vantage)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from aiohttp->alpha_vantage) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->alpha_vantage)
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->alpha_vantage)
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->alpha_vantage)
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp->alpha_vantage)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->alpha_vantage) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->alpha_vantage) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests->alpha_vantage) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->alpha_vantage) (2023.11.17)
# Downloading aiohttp-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.9 MB/s eta 0:00:0000:01
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 8.0 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 4.4 MB/s eta 0:00:00
# Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, alpha_vantage
# Successfully installed aiohttp-3.9.3 aiosignal-1.3.1 alpha_vantage-2.3.1 async-timeout-4.0.3 frozenlist-1.4.1 multidict-6.0.5 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
#import libraries
from alpha_vantage.timeseries import TimeSeries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import io

# %%
#build TimeSeries variable from Alpha Vantage API
tsl = TimeSeries(key=API_key)

# %%
#get monthly stock data of Apple
tsl.get_monthly("AAPL")
# Out:
# ({'2024-02-01': {'1. open': '183.9850',
#    '2. high': '186.9500',
#    '3. low': '183.8200',
#    '4. close': '186.8600',
#    '5. volume': '64885408'},
#   '2024-01-31': {'1. open': '187.0400',
#    '2. high': '187.0950',
#    '3. low': '184.3500',
#    '4. close': '184.4000',
#    '5. volume': '55467803'},
#   '2024-01-30': {'1. open': '190.9400',
#    '2. high': '191.8000',
#    '3. low': '187.4700',
#    '4. close': '188.0400',
#    '5. volume': '55859370'},
#   '2024-01-29': {'1. open': '192.0100',
#    '2. high': '192.2000',
#    '3. low': '189.5800',
#    '4. close': '191.7300',
#    '5. volume': '47145622'},
#   '2024-01-26': {'1. open': '194.2700',
#    '2. high': '194.7600',
#    '3. low': '191.9400',
#    '4. close': '192.4200',
#    '5. volume': '44594011'},
#   '2024-01-25': {'1. open': '195.2200',
#    '2. high': '196.2675',
#    '3. low': '193.1125',
#    '4. close': '194.1700',
#    '5. volume': '54822126'},
#   '2024-01-24': {'1. open': '195.4200',
#    '2. high': '196.3800',
#    '3. low': '194.3400',
#    '4. close': '194.5000',
#    '5. volume': '53463269'},
#   '2024-01-23': {'1. open': '195.0200',
#    '2. high': '195.7500',
#    '3. low': '193.8299',
#    '4. close': '195.1800',
#    '5. volume': '42355590'},
#   '2024-01-22': {'1. open': '192.3000',
#    '2. high': '195.3300',
#    '3. low': '192.2600',
#    '4. close': '193.8900',
#    '5. volume': '60133852'},
#   '2024-01-19': {'1. open': '189.3300',
#    '2. high': '191.9500',
#    '3. low': '188.8200',
#    '4. close': '191.5600',
#    '5. volume': '68902985'},
#   '2024-01-18': {'1. open': '186.0900',
#    '2. high': '189.1400',
#    '3. low': '185.8300',
#    '4. close': '188.6300',
#    '5. volume': '78005754'},
#   '2024-01-17': {'1. open': '181.2700',
#    '2. high': '182.9300',
#    '3. low': '180.3000',
#    '4. close': '182.6800',
#    '5. volume': '47317433'},
#   '2024-01-16': {'1. open': '182.1600',
#    '2. high': '184.2600',
#    '3. low': '180.9340',
#    '4. close': '183.6300',
#    '5. volume': '65603041'},
#   '2024-01-12': {'1. open': '186.0600',
#    '2. high': '186.7400',
#    '3. low': '185.1900',
#    '4. close': '185.9200',
#    '5. volume': '40477782'},
#   '2024-01-11': {'1. open': '186.5400',
#    '2. high': '187.0500',
#    '3. low': '183.6200',
#    '4. close': '185.5900',
#    '5. volume': '49128408'},
#   '2024-01-10': {'1. open': '184.3500',
#    '2. high': '186.4000',
#    '3. low': '183.9200',
#    '4. close': '186.1900',
#    '5. volume': '46792908'},
#   '2024-01-09': {'1. open': '183.9200',
#    '2. high': '185.1500',
#    '3. low': '182.7300',
#    '4. close': '185.1400',
#    '5. volume': '42841809'},
#   '2024-01-08': {'1. open': '182.0850',
#    '2. high': '185.6000',
#    '3. low': '181.5000',
#    '4. close': '185.5600',
#    '5. volume': '59144470'},
#   '2024-01-05': {'1. open': '181.9900',
#    '2. high': '182.7600',
#    '3. low': '180.1700',
#    '4. close': '181.1800',
#    '5. volume': '62196924'},
#   '2024-01-04': {'1. open': '182.1500',
#    '2. high': '183.0872',
#    '3. low': '180.8800',
#    '4. close': '181.9100',
#    '5. volume': '71983570'},
#   '2024-01-03': {'1. open': '184.2200',
#    '2. high': '185.8800',
#    '3. low': '183.4300',
#    '4. close': '184.2500',
#    '5. volume': '58414460'},
#   '2024-01-02': {'1. open': '187.1500',
#    '2. high': '188.4400',
#    '3. low': '183.8850',
#    '4. close': '185.6400',
#    '5. volume': '82488674'},
#   '2023-12-29': {'1. open': '193.9000',
#    '2. high': '194.4000',
#    '3. low': '191.7250',
#    '4. close': '192.5300',
#    '5. volume': '42672148'},
#   '2023-12-28': {'1. open': '194.1400',
#    '2. high': '194.6600',
#    '3. low': '193.1700',
#    '4. close': '193.5800',
#    '5. volume': '34049898'},
#   '2023-12-27': {'1. open': '192.4900',
#    '2. high': '193.5000',
#    '3. low': '191.0900',
#    '4. close': '193.1500',
#    '5. volume': '47899806'},
#   '2023-12-26': {'1. open': '193.6100',
#    '2. high': '193.8900',
#    '3. low': '192.8300',
#    '4. close': '193.0500',
#    '5. volume': '28919310'},
#   '2023-12-22': {'1. open': '195.1800',
#    '2. high': '195.4100',
#    '3. low': '192.9700',
#    '4. close': '193.6000',
#    '5. volume': '37149570'},
#   '2023-12-21': {'1. open': '196.1000',
#    '2. high': '197.0800',
#    '3. low': '193.5000',
#    '4. close': '194.6800',
#    '5. volume': '46482549'},
#   '2023-12-20': {'1. open': '196.9000',
#    '2. high': '197.6800',
#    '3. low': '194.8300',
#    '4. close': '194.8300',
#    '5. volume': '52242815'},
#   '2023-12-19': {'1. open': '196.1600',
#    '2. high': '196.9500',
#    '3. low': '195.8900',
#    '4. close': '196.9400',
#    '5. volume': '40233138'},
#   '2023-12-18': {'1. open': '196.0900',
#    '2. high': '196.6300',
#    '3. low': '194.3900',
#    '4. close': '195.8900',
#    '5. volume': '55751861'},
#   '2023-12-15': {'1. open': '197.5300',
#    '2. high': '198.3999',
#    '3. low': '197.0000',
#    '4. close': '197.5700',
#    '5. volume': '128538401'},
#   '2023-12-14': {'1. open': '198.0200',
#    '2. high': '199.6200',
#    '3. low': '196.1600',
#    '4. close': '198.1100',
#    '5. volume': '66831572'},
#   '2023-12-13': {'1. open': '195.0900',
#    '2. high': '198.0000',
#    '3. low': '194.8500',
#    '4. close': '197.9600',
#    '5. volume': '70404183'},
#   '2023-12-12': {'1. open': '193.0800',
#    '2. high': '194.7200',
#    '3. low': '191.7210',
#    '4. close': '194.7100',
#    '5. volume': '52696900'},
#   '2023-12-11': {'1. open': '193.1100',
#    '2. high': '193.4900',
#    '3. low': '191.4200',
#    '4. close': '193.1800',
#    '5. volume': '60943699'},
#   '2023-12-08': {'1. open': '194.2000',
#    '2. high': '195.9900',
#    '3. low': '193.6700',
#    '4. close': '195.7100',
#    '5. volume': '53406358'},
#   '2023-12-07': {'1. open': '193.6300',
#    '2. high': '195.0000',
#    '3. low': '193.5900',
#    '4. close': '194.2700',
#    '5. volume': '47477655'},
#   '2023-12-06': {'1. open': '194.4500',
#    '2. high': '194.7600',
#    '3. low': '192.1100',
#    '4. close': '192.3200',
#    '5. volume': '40895115'},
#   '2023-12-05': {'1. open': '190.2100',
#    '2. high': '194.4000',
#    '3. low': '190.1800',
#    '4. close': '193.4200',
#    '5. volume': '66628398'},
#   '2023-12-04': {'1. open': '189.9800',
#    '2. high': '190.0500',
#    '3. low': '187.4511',
#    '4. close': '189.4300',
#    '5. volume': '43389519'},
#   '2023-12-01': {'1. open': '190.3300',
#    '2. high': '191.5600',
#    '3. low': '189.2300',
#    '4. close': '191.2400',
#    '5. volume': '45704823'},
#   '2023-11-30': {'1. open': '189.8400',
#    '2. high': '190.3200',
#    '3. low': '188.1900',
#    '4. close': '189.9500',
#    '5. volume': '48794366'},
#   '2023-11-29': {'1. open': '190.9000',
#    '2. high': '192.0900',
#    '3. low': '188.9700',
#    '4. close': '189.3700',
#    '5. volume': '43014224'},
#   '2023-11-28': {'1. open': '189.7800',
#    '2. high': '191.0800',
#    '3. low': '189.4000',
#    '4. close': '190.4000',
#    '5. volume': '38415419'},
#   '2023-11-27': {'1. open': '189.9200',
#    '2. high': '190.6700',
#    '3. low': '188.9000',
#    '4. close': '189.7900',
#    '5. volume': '40552609'},
#   '2023-11-24': {'1. open': '190.8700',
#    '2. high': '190.9000',
#    '3. low': '189.2500',
#    '4. close': '189.9700',
#    '5. volume': '24048344'},
#   '2023-11-22': {'1. open': '191.4900',
#    '2. high': '192.9300',
#    '3. low': '190.8250',
#    '4. close': '191.3100',
#    '5. volume': '39630011'},
#   '2023-11-21': {'1. open': '191.4100',
#    '2. high': '191.5200',
#    '3. low': '189.7400',
#    '4. close': '190.6400',
#    '5. volume': '38134485'},
#   '2023-11-20': {'1. open': '189.8900',
#    '2. high': '191.9050',
#    '3. low': '189.8800',
#    '4. close': '191.4500',
#    '5. volume': '46538614'},
#   '2023-11-17': {'1. open': '190.2500',
#    '2. high': '190.3800',
#    '3. low': '188.5700',
#    '4. close': '189.6900',
#    '5. volume': '50941404'},
#   '2023-11-16': {'1. open': '189.5700',
#    '2. high': '190.9600',
#    '3. low': '188.6500',
#    '4. close': '189.7100',
#    '5. volume': '54412915'},
#   '2023-11-15': {'1. open': '187.8450',
#    '2. high': '189.5000',
#    '3. low': '187.7800',
#    '4. close': '188.0100',
#    '5. volume': '53790499'},
#   '2023-11-14': {'1. open': '187.7000',
#    '2. high': '188.1100',
#    '3. low': '186.3000',
#    '4. close': '187.4400',
#    '5. volume': '60108378'},
#   '2023-11-13': {'1. open': '185.8200',
#    '2. high': '186.0300',
#    '3. low': '184.2100',
#    '4. close': '184.8000',
#    '5. volume': '43627519'},
#   '2023-11-10': {'1. open': '183.9700',
#    '2. high': '186.5650',
#    '3. low': '183.5300',
#    '4. close': '186.4000',
#    '5. volume': '66177922'},
#   '2023-11-09': {'1. open': '182.9600',
#    '2. high': '184.1200',
#    '3. low': '181.8100',
#    '4. close': '182.4100',
#    '5. volume': '53763540'},
#   '2023-11-08': {'1. open': '182.3500',
#    '2. high': '183.4500',
#    '3. low': '181.5900',
#    '4. close': '182.8900',
#    '5. volume': '49340282'},
#   '2023-11-07': {'1. open': '179.1800',
#    '2. high': '182.4400',
#    '3. low': '178.9700',
#    '4. close': '181.8200',
#    '5. volume': '70529966'},
#   '2023-11-06': {'1. open': '176.3800',
#    '2. high': '179.4300',
#    '3. low': '176.2100',
#    '4. close': '179.2300',
#    '5. volume': '63841310'},
#   '2023-11-03': {'1. open': '174.2400',
#    '2. high': '176.8200',
#    '3. low': '173.3500',
#    '4. close': '176.6500',
#    '5. volume': '79829246'},
#   '2023-11-02': {'1. open': '175.5200',
#    '2. high': '177.7800',
#    '3. low': '175.4600',
#    '4. close': '177.5700',
#    '5. volume': '77334752'},
#   '2023-11-01': {'1. open': '171.0000',
#    '2. high': '174.2300',
#    '3. low': '170.1200',
#    '4. close': '173.9700',
#    '5. volume': '56934906'},
#   '2023-10-31': {'1. open': '169.3500',
#    '2. high': '170.9000',
#    '3. low': '167.9000',
#    '4. close': '170.7700',
#    '5. volume': '44846017'},
#   '2023-10-30': {'1. open': '169.0200',
#    '2. high': '171.1700',
#    '3. low': '168.8700',
#    '4. close': '170.2900',
#    '5. volume': '51130955'},
#   '2023-10-27': {'1. open': '166.9100',
#    '2. high': '168.9600',
#    '3. low': '166.8300',
#    '4. close': '168.2200',
#    '5. volume': '58499129'},
#   '2023-10-26': {'1. open': '170.3700',
#    '2. high': '171.3775',
#    '3. low': '165.6700',
#    '4. close': '166.8900',
#    '5. volume': '70625258'},
#   '2023-10-25': {'1. open': '171.8800',
#    '2. high': '173.0600',
#    '3. low': '170.6500',
#    '4. close': '171.1000',
#    '5. volume': '57156962'},
#   '2023-10-24': {'1. open': '173.0500',
#    '2. high': '173.6700',
#    '3. low': '171.4500',
#    '4. close': '173.4400',
#    '5. volume': '43816644'},
#   '2023-10-23': {'1. open': '170.9100',
#    '2. high': '174.0100',
#    '3. low': '169.9300',
#    '4. close': '173.0000',
#    '5. volume': '55980109'},
#   '2023-10-20': {'1. open': '175.3100',
#    '2. high': '175.4200',
#    '3. low': '172.6400',
#    '4. close': '172.8800',
#    '5. volume': '64244028'},
#   '2023-10-19': {'1. open': '176.0400',
#    '2. high': '177.8400',
#    '3. low': '175.1900',
#    '4. close': '175.4600',
#    '5. volume': '59302863'},
#   '2023-10-18': {'1. open': '175.5800',
#    '2. high': '177.5750',
#    '3. low': '175.1100',
#    '4. close': '175.8400',
#    '5. volume': '54764375'},
#   '2023-10-17': {'1. open': '176.6450',
#    '2. high': '178.4200',
#    '3. low': '174.8000',
#    '4. close': '177.1500',
#    '5. volume': '57549350'},
#   '2023-10-16': {'1. open': '176.7500',
#    '2. high': '179.0750',
#    '3. low': '176.5100',
#    '4. close': '178.7200',
#    '5. volume': '52516984'},
#   '2023-10-13': {'1. open': '181.4200',
#    '2. high': '181.9300',
#    '3. low': '178.1400',
#    '4. close': '178.8500',
#    '5. volume': '51456082'},
#   '2023-10-12': {'1. open': '180.0700',
#    '2. high': '182.3400',
#    '3. low': '179.0400',
#    '4. close': '180.7100',
#    '5. volume': '56743119'},
#   '2023-10-11': {'1. open': '178.2000',
#    '2. high': '179.8500',
#    '3. low': '177.6000',
#    '4. close': '179.8000',
#    '5. volume': '47551098'},
#   '2023-10-10': {'1. open': '178.1000',
#    '2. high': '179.7200',
#    '3. low': '177.9500',
#    '4. close': '178.3900',
#    '5. volume': '43698019'},
#   '2023-10-09': {'1. open': '176.8100',
#    '2. high': '179.0500',
#    '3. low': '175.8000',
#    '4. close': '178.9900',
#    '5. volume': '42390772'},
#   '2023-10-06': {'1. open': '173.8000',
#    '2. high': '177.9900',
#    '3. low': '173.1800',
#    '4. close': '177.4900',
#    '5. volume': '57266675'},
#   '2023-10-05': {'1. open': '173.7900',
#    '2. high': '175.4500',
#    '3. low': '172.6800',
#    '4. close': '174.9100',
#    '5. volume': '48527918'},
#   '2023-10-04': {'1. open': '171.0900',
#    '2. high': '174.2100',
#    '3. low': '170.9700',
#    '4. close': '173.6600',
#    '5. volume': '53020286'},
#   '2023-10-03': {'1. open': '172.2550',
#    '2. high': '173.6300',
#    '3. low': '170.8200',
#    '4. close': '172.4000',
#    '5. volume': '49594613'},
#   '2023-10-02': {'1. open': '171.2200',
#    '2. high': '174.3000',
#    '3. low': '170.9300',
#    '4. close': '173.7500',
#    '5. volume': '52164535'},
#   '2023-09-29': {'1. open': '172.0200',
#    '2. high': '173.0700',
#    '3. low': '170.3410',
#    '4. close': '171.2100',
#    '5. volume': '51861083'},
#   '2023-09-28': {'1. open': '169.3400',
#    '2. high': '172.0300',
#    '3. low': '167.6200',
#    '4. close': '170.6900',
#    '5. volume': '56294419'},
#   '2023-09-27': {'1. open': '172.6200',
#    '2. high': '173.0400',
#    '3. low': '169.0500',
#    '4. close': '170.4300',
#    '5. volume': '66921808'},
#   '2023-09-26': {'1. open': '174.8200',
#    '2. high': '175.2000',
#    '3. low': '171.6600',
#    '4. close': '171.9600',
#    '5. volume': '64588945'},
#   '2023-09-25': {'1. open': '174.2000',
#    '2. high': '176.9700',
#    '3. low': '174.1500',
#    '4. close': '176.0800',
#    '5. volume': '46172740'},
#   '2023-09-22': {'1. open': '174.6700',
#    '2. high': '177.0790',
#    '3. low': '174.0500',
#    '4. close': '174.7900',
#    '5. volume': '56725385'},
#   '2023-09-21': {'1. open': '174.5500',
#    '2. high': '176.3000',
#    '3. low': '173.8600',
#    '4. close': '173.9300',
#    '5. volume': '63149116'},
#   '2023-09-20': {'1. open': '179.2600',
#    '2. high': '179.6950',
#    '3. low': '175.4000',
#    '4. close': '175.4900',
#    '5. volume': '58436181'},
#   '2023-09-19': {'1. open': '177.5200',
#    '2. high': '179.6300',
#    '3. low': '177.1300',
#    '4. close': '179.0700',
#    '5. volume': '51826941'},
#   '2023-09-18': {'1. open': '176.4800',
#    '2. high': '179.3800',
#    '3. low': '176.1700',
#    '4. close': '177.9700',
#    '5. volume': '67257573'},
#   '2023-09-15': {'1. open': '176.4800',
#    '2. high': '176.4950',
#    '3. low': '173.8200',
#    '4. close': '175.0100',
#    '5. volume': '109259461'},
#   '2023-09-14': {'1. open': '174.0000',
#    '2. high': '176.1000',
#    '3. low': '173.5800',
#    '4. close': '175.7400',
#    '5. volume': '60895757'},
#   '2023-09-13': {'1. open': '176.5100',
#    '2. high': '177.3000',
#    '3. low': '173.9800',
#    '4. close': '174.2100',
#    '5. volume': '84267928'},
#   '2023-09-12': {'1. open': '179.4900',
#    '2. high': '180.1300',
#    '3. low': '174.8200',
#    '4. close': '176.3000',
#    '5. volume': '90370192'},
#   '2023-09-11': {'1. open': '180.0700',
#    '2. high': '180.3000',
#    '3. low': '177.3400',
#    '4. close': '179.3600',
#    '5. volume': '58953052'}},
#  {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2024-02-01',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'})
