# %% [markdown]
# # Exploring Alpha Vantage API

# %% [markdown]
# ### Imports- **Run First**

# %%
#open file with your API key
with open('Alpha_Vintage_API_Key.txt') as file:
    API_key = file.read()
API_key = API_key.strip()

# %%
#import libraries
from alpha_vantage.timeseries import TimeSeries

import requests
from bs4 import BeautifulSoup

import pandas as pd
import io

# %%
#build TimeSeries variable from Alpha Vantage API
ts1 = TimeSeries(key = API_key)

# %% [markdown]
# ### How to put stock data into a DataFrame

# %% [markdown]
# #### Requests Method

# %%
#get weekly stock data of Apple in DataFrame format
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=AAPL&apikey=' + str(API_key) + "&datatype=csv"
response = requests.get(url).content

data= pd.read_csv(io.StringIO(response.decode("utf-8")))
print(data)
# Out:
#        timestamp     open    high     low   close     volume
# 0     2024-02-01  192.010  192.20  183.82  186.86  223358203
# 1     2024-01-26  192.300  196.38  191.94  192.42  255368848
# 2     2024-01-19  182.160  191.95  180.30  191.56  259829213
# 3     2024-01-12  182.085  187.05  181.50  185.92  238385377
# 4     2024-01-05  187.150  188.44  180.17  181.18  275083628
# ...          ...      ...     ...     ...     ...        ...
# 1260  1999-12-10  114.560  118.00   99.00  103.00   25152800
# 1261  1999-12-03   94.250  115.56   93.25  115.00   28046300
# 1262  1999-11-26   91.750   95.50   88.50   95.06    9757600
# 1263  1999-11-19   89.620   94.75   88.06   92.44   13711000
# 1264  1999-11-12   87.750   97.73   86.75   90.62   25776200
#
# [1265 rows x 6 columns]

# %%
#get head of data
data.head(10)

# %% [markdown]
# #### Python Package Method

# %%
#store Apple stock intraday data in data and meta_data variables
apple1, meta_data=ts1.get_intraday("AAPL")

# %%
#print meta_data
print(meta_data)
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume', '2. Symbol': 'AAPL', '3. Last Refreshed': '2024-02-01 19:45:00', '4. Interval': '15min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}

# %%
#print data
print(apple1)
# Out:
# {'2024-02-01 19:45:00': {'1. open': '181.4300', '2. high': '181.6000', '3. low': '181.2100', '4. close': '181.4500', '5. volume': '138032'}, '2024-02-01 19:30:00': {'1. open': '181.1000', '2. high': '181.4300', '3. low': '181.0200', '4. close': '181.4300', '5. volume': '94512'}, '2024-02-01 19:15:00': {'1. open': '181.0600', '2. high': '181.2000', '3. low': '181.0000', '4. close': '181.1500', '5. volume': '81422'}, '2024-02-01 19:00:00': {'1. open': '180.9200', '2. high': '181.1000', '3. low': '180.7900', '4. close': '181.0800', '5. volume': '85198'}, '2024-02-01 18:45:00': {'1. open': '180.9500', '2. high': '181.2500', '3. low': '180.8200', '4. close': '180.8850', '5. volume': '124197'}, '2024-02-01 18:30:00': {'1. open': '180.7500', '2. high': '180.9500', '3. low': '180.6000', '4. close': '180.9000', '5. volume': '144110'}, '2024-02-01 18:15:00': {'1. open': '180.6600', '2. high': '180.9700', '3. low': '180.4600', '4. close': '180.8000', '5. volume': '139529'}, '2024-02-01 18:00:00': {'1. open': '180.6100', '2. high': '181.3700', '3. low': '180.2800', '4. close': '180.6600', '5. volume': '325083'}, '2024-02-01 17:45:00': {'1. open': '181.5010', '2. high': '181.8700', '3. low': '180.2100', '4. close': '180.6100', '5. volume': '658277'}, '2024-02-01 17:30:00': {'1. open': '184.0200', '2. high': '184.3900', '3. low': '179.1000', '4. close': '181.5000', '5. volume': '2137734'}, '2024-02-01 17:15:00': {'1. open': '183.3000', '2. high': '185.7800', '3. low': '182.6000', '4. close': '184.0200', '5. volume': '831516'}, '2024-02-01 17:00:00': {'1. open': '184.7100', '2. high': '184.8800', '3. low': '182.5000', '4. close': '183.3000', '5. volume': '667747'}, '2024-02-01 16:45:00': {'1. open': '183.7400', '2. high': '189.9220', '3. low': '174.4630', '4. close': '184.7100', '5. volume': '2636333'}, '2024-02-01 16:30:00': {'1. open': '188.5000', '2. high': '191.8100', '3. low': '181.5000', '4. close': '183.7000', '5. volume': '3608532'}, '2024-02-01 16:15:00': {'1. open': '187.5250', '2. high': '188.8300', '3. low': '186.2920', '4. close': '188.5000', '5. volume': '541456'}, '2024-02-01 16:00:00': {'1. open': '186.8900', '2. high': '196.0900', '3. low': '186.2100', '4. close': '187.5500', '5. volume': '13184687'}, '2024-02-01 15:45:00': {'1. open': '186.8150', '2. high': '186.9500', '3. low': '186.3600', '4. close': '186.8900', '5. volume': '5000330'}, '2024-02-01 15:30:00': {'1. open': '186.6500', '2. high': '186.9050', '3. low': '186.5000', '4. close': '186.8200', '5. volume': '1843335'}, '2024-02-01 15:15:00': {'1. open': '186.6200', '2. high': '186.8000', '3. low': '186.5500', '4. close': '186.6600', '5. volume': '1529424'}, '2024-02-01 15:00:00': {'1. open': '186.4700', '2. high': '186.7000', '3. low': '186.2800', '4. close': '186.6200', '5. volume': '1837522'}, '2024-02-01 14:45:00': {'1. open': '186.3150', '2. high': '186.6200', '3. low': '186.3150', '4. close': '186.4750', '5. volume': '1419265'}, '2024-02-01 14:30:00': {'1. open': '185.9800', '2. high': '186.4300', '3. low': '185.8810', '4. close': '186.3150', '5. volume': '1160772'}, '2024-02-01 14:15:00': {'1. open': '185.8200', '2. high': '186.1550', '3. low': '185.7600', '4. close': '185.9750', '5. volume': '1051975'}, '2024-02-01 14:00:00': {'1. open': '185.8000', '2. high': '186.1100', '3. low': '185.5500', '4. close': '185.8150', '5. volume': '1244358'}, '2024-02-01 13:45:00': {'1. open': '185.3800', '2. high': '185.9600', '3. low': '185.3800', '4. close': '185.7950', '5. volume': '972119'}, '2024-02-01 13:30:00': {'1. open': '185.7400', '2. high': '185.9000', '3. low': '185.2600', '4. close': '185.3790', '5. volume': '1147789'}, '2024-02-01 13:15:00': {'1. open': '185.9800', '2. high': '186.0700', '3. low': '185.6500', '4. close': '185.7300', '5. volume': '888107'}, '2024-02-01 13:00:00': {'1. open': '186.1300', '2. high': '186.1900', '3. low': '185.5700', '4. close': '185.9900', '5. volume': '1045196'}, '2024-02-01 12:45:00': {'1. open': '185.8200', '2. high': '186.4400 ...

# %%
#store data into a DataFrame
df_meta_data=pd.DataFrame(apple1).transpose().reset_index()
df_meta_data.head()
# Out:
#                  index   1. open   2. high    3. low  4. close 5. volume
# 0  2024-02-01 19:45:00  181.4300  181.6000  181.2100  181.4500    138032
# 1  2024-02-01 19:30:00  181.1000  181.4300  181.0200  181.4300     94512
# 2  2024-02-01 19:15:00  181.0600  181.2000  181.0000  181.1500     81422
# 3  2024-02-01 19:00:00  180.9200  181.1000  180.7900  181.0800     85198
# 4  2024-02-01 18:45:00  180.9500  181.2500  180.8200  180.8850    124197

# %%
#Bring in data in DataFrame format

# %%
# display new intraday stock data

# %%
#get full amount of intraday stock data for data and meta_data

# %%
#print meta_data

# %%
#print data with reset index
